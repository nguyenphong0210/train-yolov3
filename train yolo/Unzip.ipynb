# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# %cd /content/gdrive/My\ Drive
# Out:
# Mounted at /content/gdrive
# '[cnttqn.com] Camtasia Studio 9.0.4 Full'   Iphone
# 'Colab Notebooks'			   'train yolo.7z'
# 'eng breaking'				   'từ vựng tiếng anh'
# 'File nghe Pre full'			    yolov3
# 'Hack não 1500 từ Tiếng Anh'		    yolov4-20220213T021700Z-001.zip
# 'HACK NÃO 1500 TỪ TIẾNG ANH.docx'
# /content/gdrive/My Drive

# %%
# !unzip /mydrive/yolov4-20220213T021700Z-001.zip
# Out:
# Archive:  /mydrive/yolov4-20220213T021700Z-001.zip
#   inflating: yolov4/darknet/vcpkg.json
#   inflating: yolov4/darknet/darknet_video.py
#    creating: yolov4/darknet/backup/
#   inflating: yolov4/darknet/image_yolov3.sh
#   inflating: yolov4/darknet/video_yolov4.sh
#   inflating: yolov4/darknet/image_yolov4.sh
#   inflating: yolov4/darknet/net_cam_v4.sh
#   inflating: yolov4/darknet/json_mjpeg_streams.sh
#   inflating: yolov4/darknet/darknet_images.py
#   inflating: yolov4/darknet/video_yolov3.sh
#   inflating: yolov4/darknet/chart_yolov4_training.png
#   inflating: yolov4/darknet/darknet.py
#   inflating: yolov4/darknet/chart.png
#   inflating: yolov4/darknet/net_cam_v3.sh
#   inflating: yolov4/darknet/Makefile
#   inflating: yolov4/darknet/results/tmp.txt
#   inflating: yolov4/darknet/.gitignore
#   inflating: yolov4/darknet/DarknetConfig.cmake.in
#   inflating: yolov4/darknet/build.ps1
#   inflating: yolov4/darknet/include/darknet.h
#   inflating: yolov4/darknet/CMakeLists.txt
# ...
